# %%
#importing required libraries
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
print("libraries imported !!!")
# Out:
# libraries imported !!!

# %%
dataset = pd.read_csv(r"C:\Users\Shrishti D Hore\OneDrive\Documents\Stir_Research\corrosion_data_new.csv")
print("dataset imported !!!")
# Out:
# dataset imported !!!

# %%
dataset.head()
# Out:
#    Experiment Number  Tool Profile (P)  Rotational Speed (N)  \
# 0                  1                -1                    -1
# 1                  2                 1                    -1
# 2                  3                -1                     1
# 3                  4                 1                     1
# 4                  5                -1                    -1
#
#    Welding Speed (S)  Axial Force (F)  Corrosion pit potential/mv
# 0                 -1               -1                        -572
# 1                 -1               -1                        -591
# 2                 -1               -1                        -577
# 3                 -1               -1                        -594
# 4                  1               -1                        -575

# %%
dataset.tail()
# Out:
#     Experiment Number  Tool Profile (P)  Rotational Speed (N)  \
# 26                 27                 0                     0
# 27                 28                 0                     0
# 28                 29                 0                     0
# 29                 30                 0                     0
# 30                 31                 0                     0
#
#     Welding Speed (S)  Axial Force (F)  Corrosion pit potential/mv
# 26                  0                0                        -582
# 27                  0                0                        -581
# 28                  0                0                        -591
# 29                  0                0                        -588
# 30                  0                0                        -587

# %%
corrosion_resistance = dataset['Corrosion pit potential/mv'].unique()
print(corrosion_resistance)
# Out:
# [-572 -591 -577 -594 -575 -587 -568 -589 -569 -592 -574 -588 -573 -593
#  -576 -558 -554 -615 -557 -610 -551 -611 -618 -586 -590 -582 -581]

# %%
alpha = 0.7
plt.figure(figsize=(10,25))
sns.countplot(y ='Corrosion pit potential/mv', data=dataset, alpha=alpha)
plt.title('Corrosion Resistance')
plt.show()

# %%
plt.figure(figsize=(16,7))
Tool_Profile = sns.countplot(x='Tool Profile (P)', data=dataset)

# %%
plt.figure(figsize=(16,7))
Rotational_Speed = sns.countplot(x='Rotational Speed (N)', data=dataset)

# %%
plt.figure(figsize=(16,7))
Welding_Speed = sns.countplot(x='Welding Speed (S)', data=dataset)

# %%
plt.figure(figsize=(16,7))
Axial_Force = sns.countplot(x='Axial Force (F)', data=dataset)

# %%
plt.figure(figsize=(16,7))
Corrosion_Resistance = sns.countplot(x='Corrosion pit potential/mv', data=dataset)

# %%
plt.figure(figsize=(20,10))
cor = sns.heatmap(dataset.corr(), annot=True)

# %%
plt.figure(figsize=(20,10))
bar_age = sns.barplot(x='Experiment Number',y='Corrosion pit potential/mv',hue='Tool Profile (P)',data=dataset)

# %%
plt.figure(figsize=(20,10))
bar_age = sns.barplot(x='Experiment Number',y='Corrosion pit potential/mv',hue='Rotational Speed (N)',data=dataset)

# %%
plt.figure(figsize=(20,10))
bar_age = sns.barplot(x='Experiment Number',y='Corrosion pit potential/mv',hue='Welding Speed (S)',data=dataset)

# %%
plt.figure(figsize=(20,10))
bar_age = sns.barplot(x='Experiment Number',y='Corrosion pit potential/mv',hue='Axial Force (F)',data=dataset)
